# %% [markdown]
# <a href="https://colab.research.google.com/github/prateek14062005/SEE-22CS512/blob/main/SEEAIML22CS512.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import spacy
from nltk import ngrams
nlp=spacy.load('en_core_web_sm')
sentence="AI is the simulation of human intelligence by machine.It includes expect system NLP speech recognition and machine vision"
bigram=ngrams(sentence,2)
print("Bigrams:",list(bigram))
# Out:
# Bigrams: [('A', 'I'), ('I', ' '), (' ', 'i'), ('i', 's'), ('s', ' '), (' ', 't'), ('t', 'h'), ('h', 'e'), ('e', ' '), (' ', 's'), ('s', 'i'), ('i', 'm'), ('m', 'u'), ('u', 'l'), ('l', 'a'), ('a', 't'), ('t', 'i'), ('i', 'o'), ('o', 'n'), ('n', ' '), (' ', 'o'), ('o', 'f'), ('f', ' '), (' ', 'h'), ('h', 'u'), ('u', 'm'), ('m', 'a'), ('a', 'n'), ('n', ' '), (' ', 'i'), ('i', 'n'), ('n', 't'), ('t', 'e'), ('e', 'l'), ('l', 'l'), ('l', 'i'), ('i', 'g'), ('g', 'e'), ('e', 'n'), ('n', 'c'), ('c', 'e'), ('e', ' '), (' ', 'b'), ('b', 'y'), ('y', ' '), (' ', 'm'), ('m', 'a'), ('a', 'c'), ('c', 'h'), ('h', 'i'), ('i', 'n'), ('n', 'e'), ('e', '.'), ('.', 'I'), ('I', 't'), ('t', ' '), (' ', 'i'), ('i', 'n'), ('n', 'c'), ('c', 'l'), ('l', 'u'), ('u', 'd'), ('d', 'e'), ('e', 's'), ('s', ' '), (' ', 'e'), ('e', 'x'), ('x', 'p'), ('p', 'e'), ('e', 'c'), ('c', 't'), ('t', ' '), (' ', 's'), ('s', 'y'), ('y', 's'), ('s', 't'), ('t', 'e'), ('e', 'm'), ('m', ' '), (' ', 'N'), ('N', 'L'), ('L', 'P'), ('P', ' '), (' ', 's'), ('s', 'p'), ('p', 'e'), ('e', 'e'), ('e', 'c'), ('c', 'h'), ('h', ' '), (' ', 'r'), ('r', 'e'), ('e', 'c'), ('c', 'o'), ('o', 'g'), ('g', 'n'), ('n', 'i'), ('i', 't'), ('t', 'i'), ('i', 'o'), ('o', 'n'), ('n', ' '), (' ', 'a'), ('a', 'n'), ('n', 'd'), ('d', ' '), (' ', 'm'), ('m', 'a'), ('a', 'c'), ('c', 'h'), ('h', 'i'), ('i', 'n'), ('n', 'e'), ('e', ' '), (' ', 'v'), ('v', 'i'), ('i', 's'), ('s', 'i'), ('i', 'o'), ('o', 'n')]

# %%
import spacy
from nltk import ngrams
nlp=spacy.load('en_core_web_sm')
sentence1='AI is the simulation of human intelligence by machine.It includes expect system NLP speech recognition and machine vision'
trigram=ngrams(sentence1,3)
print("Trigrams:",list(trigram))
# Out:
# Trigrams: [('A', 'I', ' '), ('I', ' ', 'i'), (' ', 'i', 's'), ('i', 's', ' '), ('s', ' ', 't'), (' ', 't', 'h'), ('t', 'h', 'e'), ('h', 'e', ' '), ('e', ' ', 's'), (' ', 's', 'i'), ('s', 'i', 'm'), ('i', 'm', 'u'), ('m', 'u', 'l'), ('u', 'l', 'a'), ('l', 'a', 't'), ('a', 't', 'i'), ('t', 'i', 'o'), ('i', 'o', 'n'), ('o', 'n', ' '), ('n', ' ', 'o'), (' ', 'o', 'f'), ('o', 'f', ' '), ('f', ' ', 'h'), (' ', 'h', 'u'), ('h', 'u', 'm'), ('u', 'm', 'a'), ('m', 'a', 'n'), ('a', 'n', ' '), ('n', ' ', 'i'), (' ', 'i', 'n'), ('i', 'n', 't'), ('n', 't', 'e'), ('t', 'e', 'l'), ('e', 'l', 'l'), ('l', 'l', 'i'), ('l', 'i', 'g'), ('i', 'g', 'e'), ('g', 'e', 'n'), ('e', 'n', 'c'), ('n', 'c', 'e'), ('c', 'e', ' '), ('e', ' ', 'b'), (' ', 'b', 'y'), ('b', 'y', ' '), ('y', ' ', 'm'), (' ', 'm', 'a'), ('m', 'a', 'c'), ('a', 'c', 'h'), ('c', 'h', 'i'), ('h', 'i', 'n'), ('i', 'n', 'e'), ('n', 'e', '.'), ('e', '.', 'I'), ('.', 'I', 't'), ('I', 't', ' '), ('t', ' ', 'i'), (' ', 'i', 'n'), ('i', 'n', 'c'), ('n', 'c', 'l'), ('c', 'l', 'u'), ('l', 'u', 'd'), ('u', 'd', 'e'), ('d', 'e', 's'), ('e', 's', ' '), ('s', ' ', 'e'), (' ', 'e', 'x'), ('e', 'x', 'p'), ('x', 'p', 'e'), ('p', 'e', 'c'), ('e', 'c', 't'), ('c', 't', ' '), ('t', ' ', 's'), (' ', 's', 'y'), ('s', 'y', 's'), ('y', 's', 't'), ('s', 't', 'e'), ('t', 'e', 'm'), ('e', 'm', ' '), ('m', ' ', 'N'), (' ', 'N', 'L'), ('N', 'L', 'P'), ('L', 'P', ' '), ('P', ' ', 's'), (' ', 's', 'p'), ('s', 'p', 'e'), ('p', 'e', 'e'), ('e', 'e', 'c'), ('e', 'c', 'h'), ('c', 'h', ' '), ('h', ' ', 'r'), (' ', 'r', 'e'), ('r', 'e', 'c'), ('e', 'c', 'o'), ('c', 'o', 'g'), ('o', 'g', 'n'), ('g', 'n', 'i'), ('n', 'i', 't'), ('i', 't', 'i'), ('t', 'i', 'o'), ('i', 'o', 'n'), ('o', 'n', ' '), ('n', ' ', 'a'), (' ', 'a', 'n'), ('a', 'n', 'd'), ('n', 'd', ' '), ('d', ' ', 'm'), (' ', 'm', 'a'), ('m', 'a', 'c'), ('a', 'c', 'h'), ('c', 'h', 'i'), ('h', 'i', 'n'), ('i', 'n', 'e'), ('n', 'e', ' '), ('e', ' ', 'v'), (' ', 'v', 'i'), ('v', 'i', 's'), ('i', 's', 'i'), ('s', 'i', 'o'), ('i', 'o', 'n')]
